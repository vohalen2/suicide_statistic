# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_excel("/content/İntihar_İstatistikleri.xlsx")

# %%
pd.set_option('display.max_rows',None)

# %%
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#     cinsiyet   yıl  sayı             tur
# 0      erkek  2002   675          asarak
# 1      erkek  2003   784          asarak
# 2      erkek  2004   774          asarak
# 3      erkek  2005   813          asarak
# 4      erkek  2006   872          asarak
# 5      erkek  2007   888          asarak
# 6      erkek  2008   973          asarak
# 7      erkek  2009  1121          asarak
# 8      erkek  2010  1080          asarak
# 9      erkek  2011   948          asarak
# 10     erkek  2012  1199          asarak
# 11     erkek  2013  1206          asarak
# 12     erkek  2014  1098          asarak
# 13     erkek  2015  1099          asarak
# 14     erkek  2016  1126          asarak
# 15     erkek  2017  1134          asarak
# 16     erkek  2018  1222          asarak
# 17     erkek  2019  1247          asarak
# 18     kadın  2002   347          asarak
# 19     kadın  2003   461          asarak
# 20     kadın  2004   420          asarak
# 21     kadın  2005   387          asarak
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cinsiyet  358 non-null    object
#  1   yıl       358 non-null    int64
#  2   sayı      358 non-null    int64
#  3   tur       358 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 11.3+ KB

# %%
df['sayı'].mean()
# Out:
# 149.231843575419

# %%
df['sayı'].min()
# Out:
# 0

# %%
df["sayı"].max()
# Out:
# 1247

# %%
plt.figure(figsize=(20, 9));
sns.boxplot("cinsiyet", "sayı", data=df);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()
# Out:
#            yıl      sayı
# yıl   1.000000  0.054519
# sayı  0.054519  1.000000

# %%
plt.figure(figsize=(20, 10))
sns.boxplot("tur", "sayı", hue="cinsiyet", data=df)
plt.xticks(rotation = 45)
plt.title('intihar-cinsiyet tablosu');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,10))
plt.scatter(x = df.tur, y = df.sayı)
plt.title('turune gore intihar sayıları')
# Out:
# Text(0.5, 1.0, 'turune gore intihar sayıları')
